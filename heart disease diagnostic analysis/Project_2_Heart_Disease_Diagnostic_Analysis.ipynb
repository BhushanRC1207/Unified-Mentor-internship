# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heart=pd.read_csv('Heart Disease data.csv')

# %%
heart.shape
# Out:
# (1025, 14)

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.columns3
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ## Summary
# - This is a clinical dataset that contain the data related to human heart.This data contain 1025 patients data that give heart related parameter details.

# %% [markdown]
# ## Data Description
# (1) Age: Age in years
#
# (2) Sex: Sex as male or female
#
# (3) cp: Chest Pain, having four levels, (Type 1: Typical Angina, Type 2: Atypical Angina, 3: non-anginal pain, 4: asymptomatic)
#
# (4) trestbps: Resting blood pressure
#
# (5) chol: Serum Cholesterol level in mg/dl
#
# (6) fbs: Fasting blood sugar level < 120 mg/dl. Two levels (1: diabetic, 2: non-diabetic)
#
# (7) restecg: Having three levels, (Value 0 = normal; Value 1 = having ST-T wave abnormality; Value 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# (8) thalach: Maximum Heart rate achieved
#
# (9) exang: Excerise induced Angina
#
# (10) oldpeak: ST depression induced by exercise relative to rest
#
# (11) slope: the slope of the peak exercise ST segment (Value 1 = upsloping; Value 2 = flat; Value 3 = downsloping)
#
# (12) ca: number of major vessels (0-3) colored by flourosopy
#
# (13) thal: (3 = normal; 6 = fixed defect; 7 = reversible defect)
#
# (14) target: the presence of heart disease (1: Diagnosed heart diseases ;0: No diagnosed heart disease)

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
heart.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 287   71    0   1       160   302    0        1      162      0      0.4
# 40    65    0   2       160   360    0        0      151      0      0.8
# 422   57    0   0       120   354    0        1      163      1      0.6
# 761   49    0   0       130   269    0        1      163      0      0.0
# 759   61    0   0       130   330    0        0      169      0      0.0
#
#      slope  ca  thal  target
# 287      2   2     2       1
# 40       2   0     2       1
# 422      2   0     2       1
# 761      2   0     2       1
# 759      2   0     2       0

# %%
# all data in numerical form so check the duplicates data.
heart.duplicated().sum()
# Out:
# 723

# %%
heart[heart.isin(heart.iloc[0].values)].dropna()
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52.0    1   0     125.0  212.0    0        1    168.0      0      1.0
# 634  52.0    1   0     125.0  212.0    0        1    168.0      0      1.0
# 671  52.0    1   0     125.0  212.0    0        1    168.0      0      1.0
# 863  52.0    1   0     125.0  212.0    0        1    168.0      0      1.0
#
#      slope   ca  thal  target
# 0        2  2.0     3       0
# 634      2  2.0     3       0
# 671      2  2.0     3       0
# 863      2  2.0     3       0

# %%
heart[heart.isin(heart.iloc[1].values)].dropna()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 1    53.0    1  0.0     140.0  203.0    1      0.0    155.0      1      3.1
# 692  53.0    1  0.0     140.0  203.0    1      0.0    155.0      1      3.1
# 813  53.0    1  0.0     140.0  203.0    1      0.0    155.0      1      3.1
# 968  53.0    1  0.0     140.0  203.0    1      0.0    155.0      1      3.1
#
#      slope   ca  thal  target
# 1      0.0  0.0   3.0       0
# 692    0.0  0.0   3.0       0
# 813    0.0  0.0   3.0       0
# 968    0.0  0.0   3.0       0

# %%
heart[heart.isin(heart.iloc[2].values)].dropna()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 2    70.0    1  0.0     145.0  174.0    0      1.0    125.0      1      2.6
# 840  70.0    1  0.0     145.0  174.0    0      1.0    125.0      1      2.6
# 884  70.0    1  0.0     145.0  174.0    0      1.0    125.0      1      2.6
# 948  70.0    1  0.0     145.0  174.0    0      1.0    125.0      1      2.6
#
#      slope   ca  thal  target
# 2      0.0  0.0   3.0       0
# 840    0.0  0.0   3.0       0
# 884    0.0  0.0   3.0       0
# 948    0.0  0.0   3.0       0

# %%
heart[heart.isin(heart.iloc[1000].values)].dropna()
# Out:
#        age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 594   64.0    1  0.0     145.0  212.0    0        0    132.0      0      2.0
# 608   64.0    1  0.0     145.0  212.0    0        0    132.0      0      2.0
# 1000  64.0    1  0.0     145.0  212.0    0        0    132.0      0      2.0
#
#       slope   ca  thal  target
# 594       1  2.0   1.0       0
# 608       1  2.0   1.0       0
# 1000      1  2.0   1.0       0

# %%
# here, notice that most of data repeated so need drop it.

# %%
heart.drop_duplicates(keep='first',inplace=True)

# %%
heart.shape
# Out:
# (302, 14)

# %%
heart.duplicated().sum()
# Out:
# 0

# %%
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
heart[heart.isin(heart.iloc[0].values)].dropna()
# Out:
#     age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  52.0    1   0     125.0  212.0    0        1    168.0      0      1.0
#
#    slope   ca  thal  target
# 0      2  2.0     3       0

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# ### EDA
# - `numerical columns`= age,trestbps,chol,thalach,oldpeak
# - `categorical columns`= sex,cp,fbs,restcg,exang,slope,ca,thal,target

# %%
df=heart.copy()

# %%
df.shape
# Out:
# (302, 14)

# %% [markdown]
# ### Univariate Analysis Of Numerical Columns

# %% [markdown]
# ### age
# - no missing values
# - age almost normally distributed
# - no outliers

# %%
df['age'].describe()
# Out:
# count    302.00000
# mean      54.42053
# std        9.04797
# min       29.00000
# 25%       48.00000
# 50%       55.50000
# 75%       61.00000
# max       77.00000
# Name: age, dtype: float64

# %%
df['age'].plot(kind='hist',bins=15)
plt.grid()

# %%
df['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].skew()
# Out:
# -0.20374327959596905

# %%
df['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### trestbps
# - no missing values
# - trestbps almost normally distributed
# - some outliers

# %%
df['trestbps'].describe()
# Out:
# count    302.000000
# mean     131.602649
# std       17.563394
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
df['trestbps'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['trestbps'].plot(kind='hist',bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['trestbps'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['trestbps'].skew()
# Out:
# 0.7165414326647316

# %%
df['trestbps'].plot(kind='box')
plt.axhline(170,color='red')

# %%
df[df['trestbps']>170]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 29    55    0   0       180   327    0        2      117      1      3.4
# 47    66    0   0       178   228    1        1      165      1      1.0
# 87    59    0   0       174   249    0        1      143      1      0.0
# 137   64    0   0       180   325    0        1      154      1      0.0
# 151   54    1   1       192   283    0        0      195      0      0.0
# 175   56    0   0       200   288    1        0      133      1      4.0
# 343   52    1   2       172   199    1        1      162      0      0.5
# 396   68    1   2       180   274    1        0      150      1      1.6
# 528   59    1   3       178   270    0        0      145      0      4.2
#
#      slope  ca  thal  target
# 29       1   0     2       0
# 47       1   2     3       0
# 87       1   0     2       0
# 137      2   0     2       1
# 151      2   1     3       0
# 175      0   2     3       0
# ...

# %%
df['trestbps'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### chol
# - no missing values
# - +ve skew
# - outliers are present

# %%
df['chol'].describe()
# Out:
# count    302.000000
# mean     246.500000
# std       51.753489
# min      126.000000
# 25%      211.000000
# 50%      240.500000
# 75%      274.750000
# max      564.000000
# Name: chol, dtype: float64

# %%
df['chol'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['chol'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['chol'].skew()
# Out:
# 1.147332413980798

# %%
df['chol'].plot(kind='box')
plt.axhline(360,color='blue')

# %%
df[df['chol']>360]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 123   65    0   2       140   417    1        0      157      0      0.8
# 158   67    0   2       115   564    0        0      160      0      1.6
# 179   56    0   0       134   409    0        0      150      1      1.9
# 255   62    0   0       140   394    0        0      157      0      1.2
# 450   63    0   0       150   407    0        0      154      0      4.0
#
#      slope  ca  thal  target
# 123      2   1     2       1
# 158      1   0     3       1
# 179      1   2     3       0
# 255      1   0     2       1
# 450      1   3     3       0

# %%
df['chol'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### thalach (Maximum Heart rate achieved)
# - no missing values
# - almost normally ditributed
# - neglegible outliers present

# %%
df['thalach'].describe()
# Out:
# count    302.000000
# mean     149.569536
# std       22.903527
# min       71.000000
# 25%      133.250000
# 50%      152.500000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
df['thalach'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['thalach'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['thalach'].skew()
# Out:
# -0.5326712468229613

# %%
df['thalach'].plot(kind='box')
plt.axhline(87,color='red')

# %%
df[df['thalach']<87]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 267   67    1   0       120   237    0        1       71      0      1.0
#
#      slope  ca  thal  target
# 267      1   0     2       0

# %%
df['thalach'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### oldpeak
# - no missing values
# - +ve skew
# - some outliers

# %%
df['oldpeak'].describe()
# Out:
# count    302.000000
# mean       1.043046
# std        1.161452
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
df['oldpeak'].unique()
# Out:
# array([1. , 3.1, 2.6, 0. , 1.9, 4.4, 0.8, 3.2, 1.6, 3. , 0.7, 4.2, 1.5,
#        2.2, 1.1, 0.3, 0.4, 0.6, 3.4, 2.8, 1.2, 2.9, 3.6, 1.4, 0.2, 2. ,
#        5.6, 0.9, 1.8, 6.2, 4. , 2.5, 0.5, 0.1, 2.1, 2.4, 3.8, 2.3, 1.3,
#        3.5])

# %%
df['oldpeak'].plot(kind='hist',bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['oldpeak'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['oldpeak'].skew()
# Out:
# 1.266172720910219

# %%
df['oldpeak'].plot(kind='box')
plt.axhline(4,color='red')

# %%
df[df['oldpeak']>4]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 6     58    1   0       114   318    0        2      140      0      4.4
# 13    51    1   0       140   298    0        1      122      1      4.2
# 54    55    1   0       140   217    0        1      111      1      5.6
# 69    62    0   0       160   164    0        0      145      0      6.2
# 528   59    1   3       178   270    0        0      145      0      4.2
#
#      slope  ca  thal  target
# 6        0   3     1       0
# 13       1   3     3       0
# 54       0   0     3       0
# 69       0   3     3       0
# 528      0   0     3       1

# %%
df['oldpeak'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Univariate Analysis Of Categorical Columns

# %% [markdown]
# ### sex

# %%
df['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
df['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='sex'>

# %%
df['sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### cp (chest pain)

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
# Type 1: Typical Angina
(143/302)*100
# Out:
# 47.35099337748344

# %%
# Type 2: Atypical Angina
(86/302)*100
# Out:
# 28.47682119205298

# %%
# Type 3: non-anginal pain
(50/302)*100
# Out:
# 16.55629139072848

# %%
# Type 4: asymptomatic
(23/302)*100
# Out:
# 7.6158940397351

# %%
df['cp'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['cp'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='cp'>

# %%
df['cp'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### fbs
# - 0 for non-diabetic
# - 1 for diabetic

# %%
df['fbs'].value_counts()
# Out:
# 0    257
# 1     45
# Name: fbs, dtype: int64

# %%
df['fbs'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['fbs'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='fbs'>

# %%
df['fbs'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### restecg
# - Value 0 = normal; Value 1 = having ST-T wave abnormality; Value 2 = showing probable or definite left ventricular hypertrophy

# %%
df['restecg'].value_counts()
# Out:
# 1    151
# 0    147
# 2      4
# Name: restecg, dtype: int64

# %%
df['restecg'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['restecg'].value_counts().plot(kind='bar',log=True)
# Out:
# <Axes: >

# %%
df['restecg'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='restecg'>

# %%
df['restecg'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## exang

# %%
df['exang'].value_counts()
# Out:
# 0    203
# 1     99
# Name: exang, dtype: int64

# %%
df['exang'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['exang'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='exang'>

# %%
df['exang'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### slope

# %%
df['slope'].value_counts()
# Out:
# 2    141
# 1    140
# 0     21
# Name: slope, dtype: int64

# %%
df['slope'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['slope'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='slope'>

# %%
df['slope'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### ca

# %%
df['ca'].value_counts()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      4
# Name: ca, dtype: int64

# %%
df['ca'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['ca'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='ca'>

# %%
df['ca'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### thal

# %%
df['thal'].value_counts()
# Out:
# 2    165
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
df['thal'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['thal'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='thal'>

# %%
df['thal'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### target

# %%
df['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
df['target'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['target'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='target'>

# %%
df['target'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Bivariate Analysis
# ### categorical data vs categorical data

# %% [markdown]
# ### sex vs cp
# - Typical angina (73% male) (27% female)
# - Atypical angina (64% male) (36% female)
# - Non-anginal pain (59% male) (41% female)
# - Asymptomatic (83% male) (17% female)

# %%
pd.crosstab(df['sex'],df['cp'])
# Out:
# cp     0   1   2   3
# sex
# 0     39  18  35   4
# 1    104  32  51  19

# %%
pd.crosstab(df['sex'],df['cp'],normalize='columns')*100
# Out:
# cp           0     1          2          3
# sex
# 0    27.272727  36.0  40.697674  17.391304
# 1    72.727273  64.0  59.302326  82.608696

# %%
sns.heatmap(pd.crosstab(df['sex'],df['cp'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='cp', ylabel='sex'>

# %% [markdown]
# ### sex vs fbs
# - Non-diabetic (67% male) (33% female)
# - Diabetic (73% male) (27% female)

# %%
pd.crosstab(df['sex'],df['fbs'])
# Out:
# fbs    0   1
# sex
# 0     84  12
# 1    173  33

# %%
pd.crosstab(df['sex'],df['fbs'],normalize='columns')*100
# Out:
# fbs          0          1
# sex
# 0    32.684825  26.666667
# 1    67.315175  73.333333

# %%
sns.heatmap(pd.crosstab(df['sex'],df['fbs'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='fbs', ylabel='sex'>

# %% [markdown]
# ### sex vs restecg
# - Normal Value(0) (70% male) (30% female)
# - ST-T wave abnormality (68% male) (32% female)
# - Probable left ventricular hypertrophy (25% male) (75% female)

# %%
pd.crosstab(df['sex'],df['restecg'])
# Out:
# restecg    0    1  2
# sex
# 0         44   49  3
# 1        103  102  1

# %%
pd.crosstab(df['sex'],df['restecg'],normalize='columns')*100
# Out:
# restecg          0          1     2
# sex
# 0        29.931973  32.450331  75.0
# 1        70.068027  67.549669  25.0

# %%
sns.heatmap(pd.crosstab(df['sex'],df['restecg'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='restecg', ylabel='sex'>

# %% [markdown]
# ### sex vs exang (exercise induced angina)

# %%
pd.crosstab(df['sex'],df['exang'])
# Out:
# exang    0   1
# sex
# 0       74  22
# 1      129  77

# %%
pd.crosstab(df['sex'],df['exang'],normalize='columns')*100
# Out:
# exang          0          1
# sex
# 0      36.453202  22.222222
# 1      63.546798  77.777778

# %%
sns.heatmap(pd.crosstab(df['sex'],df['exang'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='exang', ylabel='sex'>

# %% [markdown]
# ### sex vs slope

# %%
pd.crosstab(df['sex'],df['slope'])
# Out:
# slope   0   1   2
# sex
# 0       5  45  46
# 1      16  95  95

# %%
pd.crosstab(df['sex'],df['slope'],normalize='columns')*100
# Out:
# slope          0          1          2
# sex
# 0      23.809524  32.142857  32.624113
# 1      76.190476  67.857143  67.375887

# %%
sns.heatmap(pd.crosstab(df['sex'],df['slope'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='slope', ylabel='sex'>

# %% [markdown]
# ### sex vs ca

# %%
pd.crosstab(df['sex'],df['ca'])
# Out:
# ca     0   1   2   3  4
# sex
# 0     64  15  13   4  0
# 1    111  50  25  16  4

# %%
pd.crosstab(df['sex'],df['ca'],normalize='columns')*100
# Out:
# ca           0          1          2     3      4
# sex
# 0    36.571429  23.076923  34.210526  20.0    0.0
# 1    63.428571  76.923077  65.789474  80.0  100.0

# %%
sns.heatmap(pd.crosstab(df['sex'],df['ca'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='ca', ylabel='sex'>

# %% [markdown]
# ### sex vs thal

# %%
pd.crosstab(df['sex'],df['thal'])
# Out:
# thal  0   1   2    3
# sex
# 0     1   1  79   15
# 1     1  17  86  102

# %%
pd.crosstab(df['sex'],df['thal'],normalize='columns')*100
# Out:
# thal     0          1          2          3
# sex
# 0     50.0   5.555556  47.878788  12.820513
# 1     50.0  94.444444  52.121212  87.179487

# %%
sns.heatmap(pd.crosstab(df['sex'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='sex'>

# %% [markdown]
# ### sex vs target
# - No Diagnosed heart disease (82% male) (17% female)
# - Diagnosed heart disease (56% male) (44% female)

# %%
pd.crosstab(df['sex'],df['target'])
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  92

# %%
pd.crosstab(df['sex'],df['target'],normalize='columns')*100
# Out:
# target          0          1
# sex
# 0       17.391304  43.902439
# 1       82.608696  56.097561

# %%
sns.heatmap(pd.crosstab(df['sex'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='sex'>

# %%
df[(df['sex']==1) & (df['target']==1)]['age'].plot(kind='kde',label='male')
df[(df['sex']==0) & (df['target']==1)]['age'].plot(kind='kde',label='female')
plt.legend()

# %%
df[(df['sex']==1) & (df['target']==0)]['age'].plot(kind='kde',label='male')
df[(df['sex']==0) & (df['target']==0)]['age'].plot(kind='kde',label='female')
plt.legend()

# %% [markdown]
# ### cp vs fbs

# %%
pd.crosstab(df['cp'],df['fbs'],normalize='columns')*100
# Out:
# fbs          0          1
# cp
# 0    48.638132  40.000000
# 1    17.509728  11.111111
# 2    26.848249  37.777778
# 3     7.003891  11.111111

# %%
sns.heatmap(pd.crosstab(df['cp'],df['fbs'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='fbs', ylabel='cp'>

# %% [markdown]
# ### cp vs restecg

# %%
pd.crosstab(df['cp'],df['restecg'],normalize='columns')*100
# Out:
# restecg          0          1     2
# cp
# 0        53.061224  41.059603  75.0
# 1        12.925170  20.529801   0.0
# 2        24.489796  32.450331  25.0
# 3         9.523810   5.960265   0.0

# %%
sns.heatmap(pd.crosstab(df['cp'],df['restecg'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='restecg', ylabel='cp'>

# %% [markdown]
# ### cp vs exang

# %%
pd.crosstab(df['cp'],df['exang'],normalize='columns')*100
# Out:
# exang          0          1
# cp
# 0      31.034483  80.808081
# 1      22.660099   4.040404
# 2      36.945813  11.111111
# 3       9.359606   4.040404

# %%
sns.heatmap(pd.crosstab(df['cp'],df['exang'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='exang', ylabel='cp'>

# %% [markdown]
# ### cp vs slope

# %%
pd.crosstab(df['cp'],df['slope'],normalize='columns')*100
# Out:
# slope          0          1          2
# cp
# 0      52.380952  60.000000  34.042553
# 1       9.523810   8.571429  25.531915
# 2      23.809524  23.571429  34.042553
# 3      14.285714   7.857143   6.382979

# %%
sns.heatmap(pd.crosstab(df['cp'],df['slope'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='slope', ylabel='cp'>

# %% [markdown]
# ### cp vs ca

# %%
pd.crosstab(df['cp'],df['ca'],normalize='columns')*100
# Out:
# ca          0          1          2     3     4
# cp
# 0   37.142857  52.307692  76.315789  70.0  25.0
# 1   21.142857  12.307692   7.894737   5.0  25.0
# 2   32.571429  30.769231   5.263158  25.0  50.0
# 3    9.142857   4.615385  10.526316   0.0   0.0

# %%
sns.heatmap(pd.crosstab(df['cp'],df['ca'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='ca', ylabel='cp'>

# %% [markdown]
# ### cp vs thal

# %%
pd.crosstab(df['cp'],df['thal'],normalize='columns')*100
# Out:
# thal     0          1          2          3
# cp
# 0     50.0  66.666667  31.515152  66.666667
# 1      0.0  11.111111  23.636364   7.692308
# 2     50.0  11.111111  36.969697  18.803419
# 3      0.0  11.111111   7.878788   6.837607

# %%
sns.heatmap(pd.crosstab(df['cp'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='cp'>

# %% [markdown]
# ### cp vs target

# %%
pd.crosstab(df['cp'],df['target'],normalize='columns')*100
# Out:
# target          0          1
# cp
# 0       75.362319  23.780488
# 1        6.521739  25.000000
# 2       13.043478  41.463415
# 3        5.072464   9.756098

# %%
sns.heatmap(pd.crosstab(df['cp'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='cp'>

# %% [markdown]
# ### fbs vs restecg

# %%
pd.crosstab(df['fbs'],df['restecg'],normalize='columns')*100
# Out:
# restecg          0          1      2
# fbs
# 0        82.312925  87.417219  100.0
# 1        17.687075  12.582781    0.0

# %%
sns.heatmap(pd.crosstab(df['fbs'],df['restecg'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='restecg', ylabel='fbs'>

# %% [markdown]
# ### fbs vs exang

# %%
pd.crosstab(df['fbs'],df['exang'],normalize='columns')*100
# Out:
# exang          0          1
# fbs
# 0      85.714286  83.838384
# 1      14.285714  16.161616

# %%
sns.heatmap(pd.crosstab(df['fbs'],df['exang'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='exang', ylabel='fbs'>

# %% [markdown]
# ### fbs vs slope

# %%
pd.crosstab(df['fbs'],df['slope'],normalize='columns')*100
# Out:
# slope          0          1          2
# fbs
# 0      71.428571  86.428571  85.815603
# 1      28.571429  13.571429  14.184397

# %%
sns.heatmap(pd.crosstab(df['fbs'],df['slope'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='slope', ylabel='fbs'>

# %% [markdown]
# ### fbs vs ca

# %%
pd.crosstab(df['fbs'],df['ca'],normalize='columns')*100
# Out:
# ca           0          1          2     3     4
# fbs
# 0    88.571429  86.153846  73.684211  75.0  75.0
# 1    11.428571  13.846154  26.315789  25.0  25.0

# %%
sns.heatmap(pd.crosstab(df['fbs'],df['ca'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='ca', ylabel='fbs'>

# %% [markdown]
# ### fbs vs thal

# %%
pd.crosstab(df['fbs'],df['thal'],normalize='columns')*100
# Out:
# thal     0          1          2          3
# fbs
# 0     50.0  72.222222  87.878788  83.760684
# 1     50.0  27.777778  12.121212  16.239316

# %%
sns.heatmap(pd.crosstab(df['fbs'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='fbs'>

# %% [markdown]
# ### fbs vs target

# %%
pd.crosstab(df['fbs'],df['target'],normalize='columns')*100
# Out:
# target          0         1
# fbs
# 0       84.057971  85.97561
# 1       15.942029  14.02439

# %%
sns.heatmap(pd.crosstab(df['fbs'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='fbs'>

# %% [markdown]
# ### restecg vs exang

# %%
pd.crosstab(df['restecg'],df['exang'],normalize='columns')*100
# Out:
# exang            0          1
# restecg
# 0        45.812808  54.545455
# 1        53.201970  43.434343
# 2         0.985222   2.020202

# %%
sns.heatmap(pd.crosstab(df['restecg'],df['exang'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='exang', ylabel='restecg'>

# %% [markdown]
# ### restecg vs slope

# %%
pd.crosstab(df['restecg'],df['slope'],normalize='columns')*100
# Out:
# slope            0          1          2
# restecg
# 0        57.142857  54.285714  41.843972
# 1        38.095238  43.571429  58.156028
# 2         4.761905   2.142857   0.000000

# %%
sns.heatmap(pd.crosstab(df['restecg'],df['slope'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='slope', ylabel='restecg'>

# %% [markdown]
# ### restecg vs ca

# %%
pd.crosstab(df['restecg'],df['ca'],normalize='columns')*100
# Out:
# ca               0          1          2     3     4
# restecg
# 0        44.000000  53.846154  55.263158  65.0  25.0
# 1        54.857143  44.615385  44.736842  30.0  75.0
# 2         1.142857   1.538462   0.000000   5.0   0.0

# %%
sns.heatmap(pd.crosstab(df['restecg'],df['ca'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='ca', ylabel='restecg'>

# %% [markdown]
# ### restecg vs thal

# %%
pd.crosstab(df['restecg'],df['thal'],normalize='columns')*100
# Out:
# thal        0          1          2          3
# restecg
# 0        50.0  55.555556  47.272727  49.572650
# 1        50.0  38.888889  51.515152  49.572650
# 2         0.0   5.555556   1.212121   0.854701

# %%
sns.heatmap(pd.crosstab(df['restecg'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='restecg'>

# %% [markdown]
# ### restecg vs target

# %%
pd.crosstab(df['restecg'],df['target'],normalize='columns')*100
# Out:
# target           0          1
# restecg
# 0        57.246377  41.463415
# 1        40.579710  57.926829
# 2         2.173913   0.609756

# %%
sns.heatmap(pd.crosstab(df['restecg'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='restecg'>

# %% [markdown]
# ### exang vs slope

# %%
pd.crosstab(df['exang'],df['slope'],normalize='columns')*100
# Out:
# slope          0          1          2
# exang
# 0      57.142857  54.285714  81.560284
# 1      42.857143  45.714286  18.439716

# %%
sns.heatmap(pd.crosstab(df['exang'],df['slope'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='slope', ylabel='exang'>

# %% [markdown]
# ### exang vs ca

# %%
pd.crosstab(df['exang'],df['ca'],normalize='columns')*100
# Out:
# ca             0          1          2     3     4
# exang
# 0      74.857143  53.846154  55.263158  65.0  75.0
# 1      25.142857  46.153846  44.736842  35.0  25.0

# %%
sns.heatmap(pd.crosstab(df['exang'],df['ca'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='ca', ylabel='exang'>

# %% [markdown]
# ### exang vs thal

# %%
pd.crosstab(df['exang'],df['thal'],normalize='columns')*100
# Out:
# thal      0          1          2         3
# exang
# 0      50.0  55.555556  81.212121  49.57265
# 1      50.0  44.444444  18.787879  50.42735

# %%
sns.heatmap(pd.crosstab(df['exang'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='exang'>

# %% [markdown]
# ### exang vs target

# %%
pd.crosstab(df['exang'],df['target'],normalize='columns')*100
# Out:
# target          0         1
# exang
# 0       44.927536  85.97561
# 1       55.072464  14.02439

# %%
sns.heatmap(pd.crosstab(df['exang'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='exang'>

# %% [markdown]
# ### slope vs ca

# %%
pd.crosstab(df['slope'],df['ca'],normalize='columns')*100
# Out:
# ca             0          1          2     3     4
# slope
# 0       8.571429   3.076923   5.263158  10.0   0.0
# 1      39.428571  53.846154  55.263158  65.0  50.0
# 2      52.000000  43.076923  39.473684  25.0  50.0

# %%
sns.heatmap(pd.crosstab(df['slope'],df['ca'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='ca', ylabel='slope'>

# %% [markdown]
# ### slope vs thal

# %%
pd.crosstab(df['slope'],df['thal'],normalize='columns')*100
# Out:
# thal      0          1          2          3
# slope
# 0       0.0  16.666667   4.848485   8.547009
# 1      50.0  72.222222  33.939394  59.829060
# 2      50.0  11.111111  61.212121  31.623932

# %%
sns.heatmap(pd.crosstab(df['slope'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='slope'>

# %% [markdown]
# ### slope vs target

# %%
pd.crosstab(df['slope'],df['target'],normalize='columns')*100
# Out:
# target          0          1
# slope
# 0        8.695652   5.487805
# 1       65.942029  29.878049
# 2       25.362319  64.634146

# %%
sns.heatmap(pd.crosstab(df['slope'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='slope'>

# %% [markdown]
# ### ca vs thal

# %%
pd.crosstab(df['ca'],df['thal'],normalize='columns')*100
# Out:
# thal      0          1          2          3
# ca
# 0     100.0  44.444444  69.090909  43.589744
# 1       0.0  22.222222  17.575758  27.350427
# 2       0.0  22.222222   8.484848  17.094017
# 3       0.0  11.111111   3.636364  10.256410
# 4       0.0   0.000000   1.212121   1.709402

# %%
sns.heatmap(pd.crosstab(df['ca'],df['thal'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='thal', ylabel='ca'>

# %% [markdown]
# ### ca vs target

# %%
pd.crosstab(df['ca'],df['target'],normalize='columns')*100
# Out:
# target          0          1
# ca
# 0       32.608696  79.268293
# 1       31.884058  12.804878
# 2       22.463768   4.268293
# 3       12.318841   1.829268
# 4        0.724638   1.829268

# %%
sns.heatmap(pd.crosstab(df['ca'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='ca'>

# %% [markdown]
# ### thal vs target

# %%
pd.crosstab(df['thal'],df['target'],normalize='columns')*100
# Out:
# target          0          1
# thal
# 0        0.724638   0.609756
# 1        8.695652   3.658537
# 2       26.086957  78.658537
# 3       64.492754  17.073171

# %%
sns.heatmap(pd.crosstab(df['thal'],df['target'],normalize='columns')*100,annot=True)
# Out:
# <Axes: xlabel='target', ylabel='thal'>

# %% [markdown]
# ## Bivariate Analysis
# ### Numerical data vs Numerical data
# ### age vs trestbps

# %%
df['age'].corr(df['trestbps'])
# Out:
# 0.28312067898080406

# %%
sns.relplot(data=df,x='age',y='trestbps',kind='scatter')
sns.displot(data=df,x='age',y='trestbps',kind='hist')

# %% [markdown]
# ### age vs chol

# %%
df['age'].corr(df['chol'])
# Out:
# 0.2072155056561177

# %%
sns.relplot(data=df,x='age',y='chol',kind='scatter')
sns.displot(data=df,x='age',y='chol',kind='hist')

# %% [markdown]
# ### age vs thalach

# %%
df['age'].corr(df['thalach'])
# Out:
# -0.39523518755348036

# %%
sns.relplot(data=df,x='age',y='thalach',kind='scatter')
sns.displot(data=df,x='age',y='thalach',kind='hist')

# %% [markdown]
# ### age vs oldpeak

# %%
df['age'].corr(df['oldpeak'])
# Out:
# 0.20603963750076112

# %%
sns.relplot(data=df,x='age',y='oldpeak',kind='scatter')
sns.displot(data=df,x='age',y='oldpeak',kind='hist')

# %% [markdown]
# ### trestbps vs chol

# %%
df['trestbps'].corr(df['chol'])
# Out:
# 0.12525628555536716

# %%
sns.relplot(data=df,x='trestbps',y='chol',kind='scatter')
sns.displot(data=df,x='trestbps',y='chol',kind='hist')

# %% [markdown]
# ### trestbps vs thalach

# %%
df['trestbps'].corr(df['thalach'])
# Out:
# -0.04802271203158559

# %%
sns.relplot(data=df,x='trestbps',y='thalach',kind='scatter')
sns.displot(data=df,x='trestbps',y='thalach',kind='hist')

# %% [markdown]
# ### trestbps vs oldpeak

# %%
df['trestbps'].corr(df['oldpeak'])
# Out:
# 0.19459995031288085

# %%
sns.relplot(data=df,x='trestbps',y='oldpeak',kind='scatter')
sns.displot(data=df,x='trestbps',y='oldpeak',kind='hist')

# %% [markdown]
# ### chol vs thalach

# %%
df['chol'].corr(df['thalach'])
# Out:
# -0.005308495794754959

# %%
sns.relplot(data=df,x='chol',y='thalach',kind='scatter')
sns.displot(data=df,x='chol',y='thalach',kind='hist')

# %% [markdown]
# ### chol vs oldpeak

# %%
df['chol'].corr(df['oldpeak'])
# Out:
# 0.050086024023738844

# %%
sns.relplot(data=df,x='chol',y='oldpeak',kind='scatter')
sns.displot(data=df,x='chol',y='oldpeak',kind='hist')

# %% [markdown]
# ### thalach vs oldpeak

# %%
df['thalach'].corr(df['oldpeak'])
# Out:
# -0.3422007459247007

# %%
sns.relplot(data=df,x='thalach',y='oldpeak',kind='scatter')
sns.displot(data=df,x='thalach',y='oldpeak',kind='hist')

# %% [markdown]
# ## Bivariate Analysis
# ### Numerical data vs categorical data
# ### sex vs age

# %%
sns.catplot(data=df,x='sex',y='age',kind='box')
sns.catplot(data=df,x='sex',y='age',kind='bar')

# %% [markdown]
# ### cp vs age

# %%
sns.catplot(data=df,x='cp',y='age',kind='box')
sns.catplot(data=df,x='cp',y='age',kind='bar')

# %% [markdown]
# ### fbs vs age

# %%
sns.catplot(data=df,x='fbs',y='age',kind='box')
sns.catplot(data=df,x='fbs',y='age',kind='bar')

# %% [markdown]
# ### restecg vs age

# %%
sns.catplot(data=df,x='restecg',y='age',kind='box')
sns.catplot(data=df,x='restecg',y='age',kind='bar')

# %% [markdown]
# ### exang vs age

# %%
sns.catplot(data=df,x='exang',y='age',kind='box')
sns.catplot(data=df,x='exang',y='age',kind='bar')

# %% [markdown]
# ### slope vs age

# %%
sns.catplot(data=df,x='slope',y='age',kind='box')
sns.catplot(data=df,x='slope',y='age',kind='bar')

# %% [markdown]
# ### ca vs age

# %%
sns.catplot(data=df,x='ca',y='age',kind='box')
sns.catplot(data=df,x='ca',y='age',kind='bar')

# %% [markdown]
# ### thal vs age

# %%
sns.catplot(data=df,x='thal',y='age',kind='box')
sns.catplot(data=df,x='thal',y='age',kind='bar')

# %% [markdown]
# ### target vs age

# %%
sns.catplot(data=df,x='target',y='age',kind='box')
sns.catplot(data=df,x='target',y='age',kind='bar')

# %% [markdown]
# ### sex vs trestbps

# %%
sns.catplot(data=df,x='sex',y='trestbps',kind='box')
sns.catplot(data=df,x='sex',y='trestbps',kind='bar')

# %% [markdown]
# ### cp vs trestbps

# %%
sns.catplot(data=df,x='cp',y='trestbps',kind='box')
sns.catplot(data=df,x='cp',y='trestbps',kind='bar')

# %% [markdown]
# ### fbs vs trestbps

# %%
sns.catplot(data=df,x='fbs',y='trestbps',kind='box')
sns.catplot(data=df,x='fbs',y='trestbps',kind='bar')

# %% [markdown]
# ### restecg vs trestbps

# %%
sns.catplot(data=df,x='restecg',y='trestbps',kind='box')
sns.catplot(data=df,x='restecg',y='trestbps',kind='bar')

# %% [markdown]
# ### exang vs trestbps

# %%
sns.catplot(data=df,x='exang',y='trestbps',kind='box')
sns.catplot(data=df,x='exang',y='trestbps',kind='bar')

# %% [markdown]
# ### slope vs trestbps

# %%
sns.catplot(data=df,x='slope',y='trestbps',kind='box')
sns.catplot(data=df,x='slope',y='trestbps',kind='bar')

# %% [markdown]
# ### ca vs trestbps

# %%
sns.catplot(data=df,x='ca',y='trestbps',kind='box')
sns.catplot(data=df,x='ca',y='trestbps',kind='bar')

# %% [markdown]
# ### thal vs trestbps

# %%
sns.catplot(data=df,x='thal',y='trestbps',kind='box')
sns.catplot(data=df,x='thal',y='trestbps',kind='bar')

# %% [markdown]
# ### target vs trestbps

# %%
sns.catplot(data=df,x='target',y='trestbps',kind='box')
sns.catplot(data=df,x='target',y='trestbps',kind='bar')

# %% [markdown]
# ### sex vs chol

# %%
sns.catplot(data=df,x='sex',y='chol',kind='box')
sns.catplot(data=df,x='sex',y='chol',kind='bar')

# %% [markdown]
# ### cp vs chol

# %%
sns.catplot(data=df,x='cp',y='chol',kind='box')
sns.catplot(data=df,x='cp',y='chol',kind='bar')

# %% [markdown]
# ### fbs vs chol

# %%
sns.catplot(data=df,x='fbs',y='chol',kind='box')
sns.catplot(data=df,x='fbs',y='chol',kind='bar')

# %% [markdown]
# ### restecg vs chol

# %%
sns.catplot(data=df,x='restecg',y='chol',kind='box')
sns.catplot(data=df,x='restecg',y='chol',kind='bar')

# %% [markdown]
# ### exang vs chol

# %%
sns.catplot(data=df,x='exang',y='chol',kind='box')
sns.catplot(data=df,x='exang',y='chol',kind='bar')

# %% [markdown]
# ### slope vs chol

# %%
sns.catplot(data=df,x='slope',y='chol',kind='box')
sns.catplot(data=df,x='slope',y='chol',kind='bar')

# %% [markdown]
# ### ca vs chol

# %%
sns.catplot(data=df,x='ca',y='chol',kind='box')
sns.catplot(data=df,x='ca',y='chol',kind='bar')

# %% [markdown]
# ### thal vs chol

# %%
sns.catplot(data=df,x='thal',y='chol',kind='box')
sns.catplot(data=df,x='thal',y='chol',kind='bar')

# %% [markdown]
# ### target vs chol

# %%
sns.catplot(data=df,x='target',y='chol',kind='box')
sns.catplot(data=df,x='target',y='chol',kind='bar')

# %% [markdown]
# ### sex vs thalach

# %%
sns.catplot(data=df,x='sex',y='thalach',kind='box')
sns.catplot(data=df,x='sex',y='thalach',kind='bar')

# %% [markdown]
# ### cp vs thalach

# %%
sns.catplot(data=df,x='cp',y='thalach',kind='box')
sns.catplot(data=df,x='cp',y='thalach',kind='bar')

# %% [markdown]
# ### fbs vs thalach

# %%
sns.catplot(data=df,x='fbs',y='thalach',kind='box')
sns.catplot(data=df,x='fbs',y='thalach',kind='bar')

# %% [markdown]
# ### restecg vs thalach

# %%
sns.catplot(data=df,x='restecg',y='thalach',kind='box')
sns.catplot(data=df,x='restecg',y='thalach',kind='bar')

# %% [markdown]
# ### exang vs thalach

# %%
sns.catplot(data=df,x='exang',y='thalach',kind='box')
sns.catplot(data=df,x='exang',y='thalach',kind='bar')

# %% [markdown]
# ### slope vs thalach

# %%
sns.catplot(data=df,x='slope',y='thalach',kind='box')
sns.catplot(data=df,x='slope',y='thalach',kind='bar')

# %% [markdown]
# ### ca vs thalach

# %%
sns.catplot(data=df,x='ca',y='thalach',kind='box')
sns.catplot(data=df,x='ca',y='thalach',kind='bar')

# %% [markdown]
# ### thal vs thalach

# %%
sns.catplot(data=df,x='thal',y='thalach',kind='box')
sns.catplot(data=df,x='thal',y='thalach',kind='bar')

# %% [markdown]
# ### target vs thalach

# %%
sns.catplot(data=df,x='target',y='thalach',kind='box')
sns.catplot(data=df,x='target',y='thalach',kind='bar')

# %% [markdown]
# ### sex vs oldpeak

# %%
sns.catplot(data=df,x='sex',y='oldpeak',kind='box')
sns.catplot(data=df,x='sex',y='oldpeak',kind='bar')

# %% [markdown]
# ### cp vs oldpeak

# %%
sns.catplot(data=df,x='cp',y='oldpeak',kind='box')
sns.catplot(data=df,x='cp',y='oldpeak',kind='bar')

# %% [markdown]
# ### fbs vs oldpeak

# %%
sns.catplot(data=df,x='fbs',y='oldpeak',kind='box')
sns.catplot(data=df,x='fbs',y='oldpeak',kind='bar')

# %% [markdown]
# ### restecg vs oldpeak

# %%
sns.catplot(data=df,x='restecg',y='oldpeak',kind='box')
sns.catplot(data=df,x='restecg',y='oldpeak',kind='bar')

# %% [markdown]
# ### exang vs oldpeak

# %%
sns.catplot(data=df,x='exang',y='oldpeak',kind='box')
sns.catplot(data=df,x='exang',y='oldpeak',kind='bar')

# %% [markdown]
# ### slope vs oldpeak

# %%
sns.catplot(data=df,x='slope',y='oldpeak',kind='box')
sns.catplot(data=df,x='slope',y='oldpeak',kind='bar')

# %% [markdown]
# ### ca vs oldpeak

# %%
sns.catplot(data=df,x='ca',y='oldpeak',kind='box')
sns.catplot(data=df,x='ca',y='oldpeak',kind='bar')

# %% [markdown]
# ### thal vs oldpeak

# %%
sns.catplot(data=df,x='thal',y='oldpeak',kind='box')
sns.catplot(data=df,x='thal',y='oldpeak',kind='bar')

# %% [markdown]
# ### target vs oldpeak

# %%
sns.catplot(data=df,x='target',y='oldpeak',kind='box')
sns.catplot(data=df,x='target',y='oldpeak',kind='bar')

# %% [markdown]
# ### Multivariate Analysis

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
df.corr()['age']
# Out:
# age         1.000000
# sex        -0.094962
# cp         -0.063107
# trestbps    0.283121
# chol        0.207216
# fbs         0.119492
# restecg    -0.111590
# thalach    -0.395235
# exang       0.093216
# oldpeak     0.206040
# slope      -0.164124
# ca          0.302261
# thal        0.065317
# target     -0.221476
# Name: age, dtype: float64

# %%
df.corr()['sex']
# Out:
# age        -0.094962
# sex         1.000000
# cp         -0.051740
# trestbps   -0.057647
# chol       -0.195571
# fbs         0.046022
# restecg    -0.060351
# thalach    -0.046439
# exang       0.143460
# oldpeak     0.098322
# slope      -0.032990
# ca          0.113060
# thal        0.211452
# target     -0.283609
# Name: sex, dtype: float64

# %%
df.corr()['cp']
# Out:
# age        -0.063107
# sex        -0.051740
# cp          1.000000
# trestbps    0.046486
# chol       -0.072682
# fbs         0.096018
# restecg     0.041561
# thalach     0.293367
# exang      -0.392937
# oldpeak    -0.146692
# slope       0.116854
# ca         -0.195356
# thal       -0.160370
# target      0.432080
# Name: cp, dtype: float64

# %%
df.corr()['trestbps']
# Out:
# age         0.283121
# sex        -0.057647
# cp          0.046486
# trestbps    1.000000
# chol        0.125256
# fbs         0.178125
# restecg    -0.115367
# thalach    -0.048023
# exang       0.068526
# oldpeak     0.194600
# slope      -0.122873
# ca          0.099248
# thal        0.062870
# target     -0.146269
# Name: trestbps, dtype: float64

# %%
df.corr()['chol']
# Out:
# age         0.207216
# sex        -0.195571
# cp         -0.072682
# trestbps    0.125256
# chol        1.000000
# fbs         0.011428
# restecg    -0.147602
# thalach    -0.005308
# exang       0.064099
# oldpeak     0.050086
# slope       0.000417
# ca          0.086878
# thal        0.096810
# target     -0.081437
# Name: chol, dtype: float64

# %%
df.corr()['fbs']
# Out:
# age         0.119492
# sex         0.046022
# cp          0.096018
# trestbps    0.178125
# chol        0.011428
# fbs         1.000000
# restecg    -0.083081
# thalach    -0.007169
# exang       0.024729
# oldpeak     0.004514
# slope      -0.058654
# ca          0.144935
# thal       -0.032752
# target     -0.026826
# Name: fbs, dtype: float64

# %%
df.corr()['restecg']
# Out:
# age        -0.111590
# sex        -0.060351
# cp          0.041561
# trestbps   -0.115367
# chol       -0.147602
# fbs        -0.083081
# restecg     1.000000
# thalach     0.041210
# exang      -0.068807
# oldpeak    -0.056251
# slope       0.090402
# ca         -0.083112
# thal       -0.010473
# target      0.134874
# Name: restecg, dtype: float64

# %%
df.corr()['thalach']
# Out:
# age        -0.395235
# sex        -0.046439
# cp          0.293367
# trestbps   -0.048023
# chol       -0.005308
# fbs        -0.007169
# restecg     0.041210
# thalach     1.000000
# exang      -0.377411
# oldpeak    -0.342201
# slope       0.384754
# ca         -0.228311
# thal       -0.094910
# target      0.419955
# Name: thalach, dtype: float64

# %%
df.corr()['exang']
# Out:
# age         0.093216
# sex         0.143460
# cp         -0.392937
# trestbps    0.068526
# chol        0.064099
# fbs         0.024729
# restecg    -0.068807
# thalach    -0.377411
# exang       1.000000
# oldpeak     0.286766
# slope      -0.256106
# ca          0.125377
# thal        0.205826
# target     -0.435601
# Name: exang, dtype: float64

# %%
df.corr()['oldpeak']
# Out:
# age         0.206040
# sex         0.098322
# cp         -0.146692
# trestbps    0.194600
# chol        0.050086
# fbs         0.004514
# restecg    -0.056251
# thalach    -0.342201
# exang       0.286766
# oldpeak     1.000000
# slope      -0.576314
# ca          0.236560
# thal        0.209090
# target     -0.429146
# Name: oldpeak, dtype: float64

# %%
df.corr()['slope']
# Out:
# age        -0.164124
# sex        -0.032990
# cp          0.116854
# trestbps   -0.122873
# chol        0.000417
# fbs        -0.058654
# restecg     0.090402
# thalach     0.384754
# exang      -0.256106
# oldpeak    -0.576314
# slope       1.000000
# ca         -0.092236
# thal       -0.103314
# target      0.343940
# Name: slope, dtype: float64

# %%
df.corr()['ca']
# Out:
# age         0.302261
# sex         0.113060
# cp         -0.195356
# trestbps    0.099248
# chol        0.086878
# fbs         0.144935
# restecg    -0.083112
# thalach    -0.228311
# exang       0.125377
# oldpeak     0.236560
# slope      -0.092236
# ca          1.000000
# thal        0.160085
# target     -0.408992
# Name: ca, dtype: float64

# %%
df.corr()['thal']
# Out:
# age         0.065317
# sex         0.211452
# cp         -0.160370
# trestbps    0.062870
# chol        0.096810
# fbs        -0.032752
# restecg    -0.010473
# thalach    -0.094910
# exang       0.205826
# oldpeak     0.209090
# slope      -0.103314
# ca          0.160085
# thal        1.000000
# target     -0.343101
# Name: thal, dtype: float64

# %%
df.corr()['target']
# Out:
# age        -0.221476
# sex        -0.283609
# cp          0.432080
# trestbps   -0.146269
# chol       -0.081437
# fbs        -0.026826
# restecg     0.134874
# thalach     0.419955
# exang      -0.435601
# oldpeak    -0.429146
# slope       0.343940
# ca         -0.408992
# thal       -0.343101
# target      1.000000
# Name: target, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(heart.corr(),linewidth=0.5,annot=True)
# Out:
# <Axes: >
